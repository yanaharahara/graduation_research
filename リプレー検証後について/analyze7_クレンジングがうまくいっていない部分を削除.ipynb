# %%
import pandas as pd

# %%
#データ読み込み&表示
#df = pd.read_csv('data/allgame_result.csv')
df = pd.read_csv('data/allgame_result_corrected.csv')
display(df.head())
length = df.shape[0]
print(length)
# Out:
#    投球数      球種       球速   結果     投手     打者  スコア  アウトカウント
# 0    1   ストレート  147km/h   中飛  菅野 智之  大島 洋平  0-0        1
# 1    1   ストレート  144km/h  ボール  菅野 智之  岡林 勇希  0-0        2
# 2    2  カットボール  139km/h  見逃し  菅野 智之  岡林 勇希  0-0        2
# 3    3   スライダー  132km/h  二ゴロ  菅野 智之  岡林 勇希  0-0        2
# 4    1   ツーシーム  147km/h  ボール  菅野 智之  福留 孝介  0-0        3
# 238233

# %%
#13218
df[13216:13219]
#array = [13216,13217,13218]
# Out:
#        投球数      球種       球速             結果    投手     打者  スコア  アウトカウント
# 13216    1   ストレート  145km/h            見逃し  宮川 哲  安田 尚憲  0-3        1
# 13217    2   ストレート  146km/h            ボール  宮川 哲  安田 尚憲  0-3        1
# 13218    3  パワーカーブ        -  ボール  [ワンバウンド]  宮川 哲  安田 尚憲  0-3        1

# %%
#20557
df[20556:20559]
#array = [13216,13217,13218,20556,20557]
# Out:
#        投球数      球種       球速   結果     投手     打者  スコア  アウトカウント
# 20556    1  縦スライダー  130km/h  ボール  山岡 泰輔  藤原 恭大  0-0        2
# 20557    2  縦スライダー        -  見逃し  山岡 泰輔  藤原 恭大  0-0        2
# 20558    1  縦スライダー  130km/h  ボール  山岡 泰輔  藤原 恭大  0-0        3

# %%
#40828
df[40821:40825]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824]
# Out:
#        投球数    球種       球速                            結果     投手     打者  スコア  \
# 40821    1  フォーク  139km/h                  ボール  [送球できず]  田中 靖洋  吉田 正尚  3-2
# 40822    2  フォーク  138km/h                           ボール  田中 靖洋  吉田 正尚  3-2
# 40823    3  フォーク  141km/h                           見逃し  田中 靖洋  吉田 正尚  3-2
# 40824    4  フォーク  137km/h  ボール  [送球がバウンド、リプレー検証後判定変わらず]  田中 靖洋  吉田 正尚  3-2
#
#        アウトカウント
# 40821        2
# 40822        2
# 40823        2
# 40824        2

# %%
#55916
df[55915:55917]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916]
# Out:
#        投球数     球種       球速             結果     投手     打者  スコア  アウトカウント
# 55915    1  ストレート  145km/h            見逃し  吉田 輝星  オグレディ  0-3        2
# 55916    2  ストレート        -  ボール  [ピッチアウト]  吉田 輝星  オグレディ  0-3        2

# %%
#63484
df[63477:63479]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478]
# Out:
#        投球数       球種       球速                    結果    投手      打者  スコア  アウトカウント
# 63477    1  チェンジアップ  122km/h                   見逃し  岸 孝之  佐藤 都志也  0-0        1
# 63478    2    ストレート  141km/h  見逃し  [リプレー検証後判定変わらず]  岸 孝之  佐藤 都志也  0-0        1

# %%
#77486
df[77485:77488]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486]
# Out:
#        投球数       球種       球速   結果   投手     打者  スコア  アウトカウント
# 77485    1  チェンジアップ  132km/h  ボール  エンス  今川 優馬  2-0        2
# 77486    2   カットボール  134km/h  ボール  エンス  今川 優馬  2-0        2
# 77487    1  チェンジアップ  132km/h  ボール  エンス  今川 優馬  2-0        3

# %%
#85367
df[85366:85369]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367]
# Out:
#        投球数     球種       球速   結果     投手     打者  スコア  アウトカウント
# 85366    1   フォーク  137km/h  見逃し  谷川 昌希  吉川 尚輝  5-4        1
# 85367    2  ストレート  147km/h  ボール  谷川 昌希  吉川 尚輝  5-4        1
# 85368    1   フォーク  137km/h  見逃し  谷川 昌希  吉川 尚輝  5-4        1

# %%
#87740
df[87739:87742]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367
#87739,87740]
# Out:
#        投球数       球種       球速             結果     投手      打者  スコア  アウトカウント
# 87739    1  チェンジアップ  126km/h  ボール  [ワンバウンド]  伊藤 将司  エチェバリア  0-1        2
# 87740    2    ストレート  141km/h            見逃し  伊藤 将司  エチェバリア  0-1        2
# 87741    1  チェンジアップ  126km/h  ボール  [ワンバウンド]  伊藤 将司  エチェバリア  0-1        3

# %%
#95707
df[95704:95707]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367
#87739,87740,95704,95705]
# Out:
#        投球数     球種       球速                    結果     投手     打者  スコア  アウトカウント
# 95704    1  ストレート  149km/h                   空振り  高橋 奎二  山川 穂高  2-0        2
# 95705    2  スライダー  116km/h  ボール  [リプレー検証後判定変わらず]  高橋 奎二  山川 穂高  2-0        2
# 95706    1  ストレート  149km/h                   空振り  高橋 奎二  山川 穂高  2-0        2

# %%
#96919
df[96918:96921]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367
#87739,87740,95704,95705,96918,96919]
# Out:
#        投球数     球種       球速            結果     投手      打者  スコア  アウトカウント
# 96918    1  ストレート  149km/h           見逃し  森下 暢仁  杉本 裕太郎  2-2        2
# 96919    2  ストレート  147km/h  ボール  [送球できず]  森下 暢仁  杉本 裕太郎  2-2        2
# 96920    1  ストレート  149km/h           見逃し  森下 暢仁  杉本 裕太郎  2-2        2

# %%
#113291
df[113289:113293]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367
#87739,87740,95704,95705,96918,96919,113289,113290,113291
#]
# Out:
#         投球数     球種       球速   結果    投手     打者  スコア  アウトカウント
# 113289    1  スライダー        -  見逃し  西 純矢  蝦名 達夫  0-0        1
# 113290    2  ストレート  147km/h  ボール  西 純矢  蝦名 達夫  0-0        1
# 113291    3  スライダー  128km/h  見逃し  西 純矢  蝦名 達夫  0-0        1
# 113292    1  スライダー        -  見逃し  西 純矢  蝦名 達夫  0-0        2

# %%
#129993
df[129985:129988]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986]
# Out:
#         投球数     球種       球速                    結果    投手     打者  スコア  アウトカウント
# 129985    1  ストレート  146km/h        空振り  [ハーフスイング]  根尾 昂  佐藤 輝明  4-2        0
# 129986    2  ストレート  146km/h  ボール  [リプレー検証後判定変わらず]  根尾 昂  佐藤 輝明  4-2        0
# 129987    1  ストレート  146km/h        空振り  [ハーフスイング]  根尾 昂  佐藤 輝明  4-2        1

# %%
#149656
df[149649:149653]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651]
# Out:
#         投球数       球種       球速                              結果     投手     打者  \
# 149649    1  ナックルカーブ  119km/h                             ボール  森脇 亮介  今川 優馬
# 149650    2  ナックルカーブ  119km/h                            ファウル  森脇 亮介  今川 優馬
# 149651    3     フォーク  128km/h  ファウル  [ポール際、苦笑い、リプレー検証後判定変わらず]  森脇 亮介  今川 優馬
# 149652    1  ナックルカーブ  119km/h                             ボール  森脇 亮介  今川 優馬
#
#         スコア  アウトカウント
# 149649  4-2        0
# 149650  4-2        0
# 149651  4-2        0
# 149652  4-2        1

# %%
#153653
df[153647:153651]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#]
# Out:
#         投球数     球種       球速                           結果     投手     打者  スコア  \
# 153647    1  ストレート  144km/h                         ファウル  大貫 晋一  岡林 勇希  0-0
# 153648    2  スプリット  138km/h                          ボール  大貫 晋一  岡林 勇希  0-0
# 153649    3  スプリット  136km/h  空振り  [ランエンドヒット、リプレー検証後判定覆る]  大貫 晋一  岡林 勇希  0-0
# 153650    1  ストレート  144km/h                         ファウル  大貫 晋一  岡林 勇希  0-0
#
#         アウトカウント
# 153647        1
# 153648        1
# 153649        1
# 153650        2

# %%
#158179
df[158171:158176]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,]
# Out:
#         投球数     球種       球速                             結果    投手    打者  スコア  \
# 158171    1  ストレート  144km/h                            ボール  堀 瑞輝  レアード  7-5
# 158172    2  ストレート  145km/h                            ボール  堀 瑞輝  レアード  7-5
# 158173    3  ストレート  141km/h                           ファウル  堀 瑞輝  レアード  7-5
# 158174    4  ストレート  144km/h  空振り  [ランエンドヒット、リプレー検証後判定変わらず]  堀 瑞輝  レアード  7-5
# 158175    1  ストレート  144km/h                            ボール  堀 瑞輝  レアード  7-5
#
#         アウトカウント
# 158171        1
# 158172        1
# 158173        1
# 158174        1
# 158175        2

# %%
#160383
df[160376:160379]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377]
# Out:
#         投球数       球種       球速                  結果     投手     打者  スコア  アウトカウント
# 160376    1  チェンジアップ  113km/h                 ボール  小川 泰弘  佐藤 輝明  0-3        1
# 160377    2  チェンジアップ  113km/h  見逃し  [リプレー検証後判定覆る]  小川 泰弘  佐藤 輝明  0-3        1
# 160378    1  チェンジアップ  113km/h                 ボール  小川 泰弘  佐藤 輝明  0-3        2

# %%
#178925
df[178921:178927]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925]
# Out:
#         投球数     球種       球速                          結果     投手     打者  スコア  \
# 178921    1  スライダー  130km/h                         ボール  野村 祐輔  青木 宣親  1-3
# 178922    2  ストレート  137km/h                        ファウル  野村 祐輔  青木 宣親  1-3
# 178923    3    カーブ  113km/h  ファウル  [ライン際、リプレー検証後判定変わらず]  野村 祐輔  青木 宣親  1-3
# 178924    4  ツーシーム  138km/h                        ファウル  野村 祐輔  青木 宣親  1-3
# 178925    5  ストレート  137km/h               ボール  [ボール見失う]  野村 祐輔  青木 宣親  1-3
# 178926    1  スライダー  130km/h                         ボール  野村 祐輔  青木 宣親  1-3
#
#         アウトカウント
# 178921        2
# 178922        2
# 178923        2
# 178924        2
# 178925        2
# 178926        3

# %%
#186974
df[186966:186970]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968]
# Out:
#         投球数     球種       球速                        結果     投手     打者  スコア  \
# 186966    1  ストレート  147km/h                       ボール  髙橋 宏斗  秋山 翔吾  0-0
# 186967    2  スプリット  137km/h                       ボール  髙橋 宏斗  秋山 翔吾  0-0
# 186968    3  ストレート  150km/h  見逃し  [観客ため息、リプレー検証後判定覆る]  髙橋 宏斗  秋山 翔吾  0-0
# 186969    1  ストレート  147km/h                       ボール  髙橋 宏斗  秋山 翔吾  0-0
#
#         アウトカウント
# 186966        1
# 186967        1
# 186968        1
# 186969        2

# %%
#191440
df[191432:191437]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435]
# Out:
#         投球数       球種       球速                          結果     投手     打者  スコア  \
# 191432    1    ストレート  140km/h                         見逃し  石田 健大  堂林 翔太  1-5
# 191433    2  チェンジアップ  128km/h                        ファウル  石田 健大  堂林 翔太  1-5
# 191434    3    ストレート  141km/h                         ボール  石田 健大  堂林 翔太  1-5
# 191435    4    スライダー  125km/h  ファウル  [ポール際、リプレー検証後判定変わらず]  石田 健大  堂林 翔太  1-5
# 191436    1    ストレート  140km/h                         見逃し  石田 健大  堂林 翔太  1-5
#
#         アウトカウント
# 191432        0
# 191433        0
# 191434        0
# 191435        0
# 191436        1

# %%
#197807
df[197798:197802]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,]
# Out:
#         投球数      球種       球速                           結果    投手     打者  スコア  \
# 197798    1   ストレート  137km/h        ボール  [セーフティバント、バント構え]  美馬 学  外崎 修汰  0-0
# 197799    2  カットボール  139km/h                          ボール  美馬 学  外崎 修汰  0-0
# 197800    3   ストレート        -  空振り  [ヒットエンドラン、リプレー検証後判定覆る]  美馬 学  外崎 修汰  0-0
# 197801    1   ストレート  137km/h        ボール  [セーフティバント、バント構え]  美馬 学  外崎 修汰  0-0
#
#         アウトカウント
# 197798        1
# 197799        1
# 197800        1
# 197801        2

# %%
#203104
df[203101:203106]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104]
# Out:
#         投球数     球種       球速                結果     投手     打者  スコア  アウトカウント
# 203101    1  ストレート  149km/h               空振り  伊勢 大夢  山田 哲人  5-4        2
# 203102    2   フォーク  138km/h               空振り  伊勢 大夢  山田 哲人  5-4        2
# 203103    3  ストレート  150km/h  ファウル  [ランエンドヒット]  伊勢 大夢  山田 哲人  5-4        2
# 203104    4   フォーク  138km/h     ボール  [ワンバウンド]  伊勢 大夢  山田 哲人  5-4        2
# 203105    1  ストレート  149km/h               空振り  伊勢 大夢  山田 哲人  5-4        3

# %%
#208553
df[208548:208551]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549]
# Out:
#         投球数       球種       球速                    結果      投手     打者  スコア  \
# 208548    1  チェンジアップ  127km/h                   ボール  上田 洸太朗  大田 泰示  0-3
# 208549    2   カットボール  131km/h  ボール  [リプレー検証後判定変わらず]  上田 洸太朗  大田 泰示  0-3
# 208550    1  チェンジアップ  127km/h                   ボール  上田 洸太朗  大田 泰示  0-3
#
#         アウトカウント
# 208548        1
# 208549        1
# 208550        2

# %%
#215811
df[215806:215810]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549,215806,215807,215808]
# Out:
#         投球数     球種       球速                            結果     投手   打者  スコア  \
# 215806    1  ストレート  148km/h                          ファウル  岩貞 祐太  オスナ  5-5
# 215807    2   フォーク  140km/h                 ボール  [ワンバウンド]  岩貞 祐太  オスナ  5-5
# 215808    3   フォーク  138km/h  ボール  [送球がバウンド、リプレー検証後判定変わらず]  岩貞 祐太  オスナ  5-5
# 215809    1  ストレート  148km/h                          ファウル  岩貞 祐太  オスナ  5-5
#
#         アウトカウント
# 215806        2
# 215807        2
# 215808        2
# 215809        2

# %%
#220008
df[219998:220004]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549,215806,215807,215808,219998,219999,
#220000,220001,220002,]
# Out:
#         投球数     球種       球速                                     結果        投手  \
# 219998    1  ツーシーム  156km/h                       ファウル  [ランエンドヒット]  R.マルティネス
# 219999    2  ストレート  154km/h                         ボール  [ハーフスイング]  R.マルティネス
# 220000    3  ツーシーム  155km/h                                    ボール  R.マルティネス
# 220001    4  ストレート  153km/h                                    空振り  R.マルティネス
# 220002    5  ストレート  155km/h  ボール  [ランエンドヒット、送球がバウンド、リプレー検証後判定変わらず]  R.マルティネス
# 220003    1  ツーシーム  156km/h                       ファウル  [ランエンドヒット]  R.マルティネス
#
#           打者  スコア  アウトカウント
# 219998  ポランコ  1-1        1
# 219999  ポランコ  1-1        1
# 220000  ポランコ  1-1        1
# 220001  ポランコ  1-1        1
# 220002  ポランコ  1-1        1
# 220003  ポランコ  1-1        2

# %%
#222380
df[222372:222376]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549,215806,215807,215808,219998,219999,
#220000,220001,220002,222372,222373,222374,]
# Out:
#         投球数     球種       球速                             結果     投手     打者  スコア  \
# 222372    1  ストレート  143km/h                            ボール  大貫 晋一  長岡 秀樹  0-0
# 222373    2  ストレート  142km/h                            見逃し  大貫 晋一  長岡 秀樹  0-0
# 222374    3  スプリット  135km/h  空振り  [ランエンドヒット、リプレー検証後判定変わらず]  大貫 晋一  長岡 秀樹  0-0
# 222375    1  ストレート  143km/h                            ボール  大貫 晋一  長岡 秀樹  0-0
#
#         アウトカウント
# 222372        1
# 222373        1
# 222374        1
# 222375        2

# %%
#225147
df[225146:225149]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549,215806,215807,215808,219998,219999,
#220000,220001,220002,222372,222373,222374,225146,225147]
# Out:
#         投球数     球種       球速                            結果     投手     打者  スコア  \
# 225146    1  ストレート  148km/h                           ボール  伊勢 大夢  岡林 勇希  1-0
# 225147    2  ストレート  148km/h  見逃し  [送球がバウンド、リプレー検証後判定変わらず]  伊勢 大夢  岡林 勇希  1-0
# 225148    1  ストレート  148km/h                           ボール  伊勢 大夢  岡林 勇希  1-0
#
#         アウトカウント
# 225146        2
# 225147        2
# 225148        3

# %%
#229690
df[229685:229688]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549,215806,215807,215808,219998,219999,
#220000,220001,220002,222372,222373,222374,225146,225147,
#229685,229686]
# Out:
#         投球数     球種       球速                                       結果     投手  \
# 229685    1  ストレート  144km/h                             ボール  [バント構え]  田中 将大
# 229686    2  スライダー  133km/h  空振り  [バスターエンドラン、ヘッドスライディング、リプレー検証後判定覆る]  田中 将大
# 229687    1  ストレート  144km/h                             ボール  [バント構え]  田中 将大
#
#         打者  スコア  アウトカウント
# 229685  愛斗  0-0        0
# 229686  愛斗  0-0        0
# 229687  愛斗  0-0        1

# %%
#232252
df[232249:232254]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549,215806,215807,215808,219998,219999,
#220000,220001,220002,222372,222373,222374,225146,225147,
#229685,229686,232249,232250,232251,232252]
# Out:
#         投球数       球種       球速                結果   投手     打者  スコア  アウトカウント
# 232249    1  チェンジアップ  130km/h               見逃し  エンス  浅村 栄斗  2-0        0
# 232250    2    ストレート  146km/h  ボール  [高めのつり球を要求]  エンス  浅村 栄斗  2-0        0
# 232251    3    ストレート  146km/h               ボール  エンス  浅村 栄斗  2-0        0
# 232252    4   カットボール  133km/h               ボール  エンス  浅村 栄斗  2-0        0
# 232253    1  チェンジアップ  130km/h               見逃し  エンス  浅村 栄斗  2-0        0

# %%
#237611
df[237603:237608]
#array = [13216,13217,13218,20556,20557,40821,40822,40823,
#40824,55915,55916,63477,63478,77485,77486,85366,85367,
#87739,87740,95704,95705,96918,96919,113289,113290,113291,
#129985,129986,149649,149650,149651,153647,153648,153649,
#158171,158172,158173,158174,160376,160377,178921,178922,
#178923,178924,178925,186966,186967,186968,191432,191433,
#191434,191435,197798,197799,197800,203101,203102,203103,
#203104,208548,208549,215806,215807,215808,219998,219999,
#220000,220001,220002,222372,222373,222374,225146,225147,
#229685,229686,232249,232250,232251,232252,237603,237604,
#,237605,237606]
# Out:
#         投球数     球種       球速                        結果     投手     打者  スコア  \
# 237603    1  スライダー  142km/h                       ボール  増田 達至  今宮 健太  1-4
# 237604    2  ストレート  148km/h                       ボール  増田 達至  今宮 健太  1-4
# 237605    3  ストレート  146km/h                       空振り  増田 達至  今宮 健太  1-4
# 237606    4  ストレート  147km/h  ファウル  [ポール際、リプレー検証後判定覆る]  増田 達至  今宮 健太  1-4
# 237607    1  スライダー  142km/h                       ボール  増田 達至  今宮 健太  1-4
#
#         アウトカウント
# 237603        1
# 237604        1
# 237605        1
# 237606        1
# 237607        2

# %%
array = [13216,13217,13218,20556,20557,40821,40822,40823,
40824,55915,55916,63477,63478,77485,77486,85366,85367,
87739,87740,95704,95705,96918,96919,113289,113290,113291,
129985,129986,149649,149650,149651,153647,153648,153649,
158171,158172,158173,158174,160376,160377,178921,178922,
178923,178924,178925,186966,186967,186968,191432,191433,
191434,191435,197798,197799,197800,203101,203102,203103,
203104,208548,208549,215806,215807,215808,219998,219999,
220000,220001,220002,222372,222373,222374,225146,225147,
229685,229686,232249,232250,232251,232252,237603,237604,
237605,237606]
print(array)
print(len(array))
# Out:
# [13216, 13217, 13218, 20556, 20557, 40821, 40822, 40823, 40824, 55915, 55916, 63477, 63478, 77485, 77486, 85366, 85367, 87739, 87740, 95704, 95705, 96918, 96919, 113289, 113290, 113291, 129985, 129986, 149649, 149650, 149651, 153647, 153648, 153649, 158171, 158172, 158173, 158174, 160376, 160377, 178921, 178922, 178923, 178924, 178925, 186966, 186967, 186968, 191432, 191433, 191434, 191435, 197798, 197799, 197800, 203101, 203102, 203103, 203104, 208548, 208549, 215806, 215807, 215808, 219998, 219999, 220000, 220001, 220002, 222372, 222373, 222374, 225146, 225147, 229685, 229686, 232249, 232250, 232251, 232252, 237603, 237604, 237605, 237606]
# 84

# %%
#該当箇所を削除&データフレームの該当箇所が削除されたかを確認
df = df.drop(df.index[[array]])
length = df.shape[0]
print(length)
print(238233-84)

#indexを振り直す
df = df.reset_index(drop=True)
# Out:
# 238149
# 238149
# C:\Users\yutay\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4616: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)

# %%
df.to_csv('data/allgame_result_corrected.csv',index=False)
