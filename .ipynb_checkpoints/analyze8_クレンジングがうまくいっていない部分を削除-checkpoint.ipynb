# %%
import pandas as pd

# %%
#データ読み込み&表示
#df = pd.read_csv('data/allgame_result.csv')
df = pd.read_csv('data/allgame_result_corrected.csv')
display(df.head())
length = df.shape[0]
print(length)
# Out:
#    投球数      球種       球速   結果     投手     打者  スコア  アウトカウント
# 0    1   ストレート  147km/h   中飛  菅野 智之  大島 洋平  0-0        1
# 1    1   ストレート  144km/h  ボール  菅野 智之  岡林 勇希  0-0        2
# 2    2  カットボール  139km/h  見逃し  菅野 智之  岡林 勇希  0-0        2
# 3    3   スライダー  132km/h  二ゴロ  菅野 智之  岡林 勇希  0-0        2
# 4    1   ツーシーム  147km/h  ボール  菅野 智之  福留 孝介  0-0        3
# 238149

# %%
#3068
df[3061:3064]
#array = [3061,3062]
# Out:
#       投球数     球種       球速                          結果    投手      打者  スコア  \
# 3061    1    カーブ  119km/h                         見逃し  東浜 巨  清宮 幸太郎  1-1
# 3062    2  ストレート  147km/h  ファウル  [ポール際、リプレー検証後判定変わらず]  東浜 巨  清宮 幸太郎  1-1
# 3063    1    カーブ  119km/h                         見逃し  東浜 巨  清宮 幸太郎  1-1
#
#       アウトカウント
# 3061        2
# 3062        2
# 3063        2

# %%
#15103
df[15096:15100]
#array = [3061,3062,15096,15097,15098]
# Out:
#        投球数       球種       球速                                      結果   投手  \
# 15096    1   カットボール  142km/h                                     ボール  ロメロ
# 15097    2    ツーシーム  148km/h                                    ファウル  ロメロ
# 15098    3  チェンジアップ  135km/h  ボール  [ワンバウンド、ヘッドスライディング、リプレー検証後判定変わらず]  ロメロ
# 15099    1   カットボール  142km/h                                     ボール  ロメロ
#
#           打者  スコア  アウトカウント
# 15096  近本 光司  0-4        1
# 15097  近本 光司  0-4        1
# 15098  近本 光司  0-4        1
# 15099  近本 光司  0-4        1

# %%
#27203
df[27195:27200]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#]
# Out:
#        投球数      球種       球速                          結果     投手     打者  スコア  \
# 27195    1   ストレート  141km/h                         見逃し  山﨑 福也  鈴木 将平  0-0
# 27196    2   ストレート  143km/h                        ファウル  山﨑 福也  鈴木 将平  0-0
# 27197    3  カットボール  130km/h                         ボール  山﨑 福也  鈴木 将平  0-0
# 27198    4  カットボール  131km/h  ボール  [送球がバウンド、リプレー検証後判定覆る]  山﨑 福也  鈴木 将平  0-0
# 27199    1   ストレート  141km/h                         見逃し  山﨑 福也  鈴木 将平  0-0
#
#        アウトカウント
# 27195        1
# 27196        1
# 27197        1
# 27198        1
# 27199        2

# %%
#36871
df[36863:36866]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,]
# Out:
#        投球数     球種       球速                             結果     投手     打者  スコア  \
# 36863    1  ストレート  142km/h                            空振り  早川 隆久  柘植 世那  0-1
# 36864    2  ストレート  142km/h  空振り  [ランエンドヒット、リプレー検証後判定変わらず]  早川 隆久  柘植 世那  0-1
# 36865    1  ストレート  142km/h                            空振り  早川 隆久  柘植 世那  0-1
#
#        アウトカウント
# 36863        1
# 36864        1
# 36865        2

# %%
#38914
df[38909:38912]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910]
# Out:
#        投球数      球種       球速                           結果     投手      打者  スコア  \
# 38909    1   ストレート  152km/h                          ボール  益田 直也  紅林 弘太郎  2-1
# 38910    2  カットボール  138km/h  ボール  [ワンバウンド、リプレー検証後判定変わらず]  益田 直也  紅林 弘太郎  2-1
# 38911    1   ストレート  152km/h                          ボール  益田 直也  紅林 弘太郎  2-1
#
#        アウトカウント
# 38909        1
# 38910        1
# 38911        1

# %%
#40572
df[40569:40574]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572]
# Out:
#        投球数       球種       球速                                            結果  \
# 40569    1    ストレート  151km/h                                           見逃し
# 40570    2    ストレート  152km/h                                           ボール
# 40571    3    ストレート  149km/h                                           見逃し
# 40572    4  ナックルカーブ  121km/h  ボール  [ランエンドヒット、ワンバウンド、送球がバウンド、リプレー検証後判定変わらず]
# 40573    1    ストレート  151km/h                                           見逃し
#
#            投手     打者  スコア  アウトカウント
# 40569  山﨑 颯一郎  中村 奨吾  0-0        1
# 40570  山﨑 颯一郎  中村 奨吾  0-0        1
# 40571  山﨑 颯一郎  中村 奨吾  0-0        1
# 40572  山﨑 颯一郎  中村 奨吾  0-0        1
# 40573  山﨑 颯一郎  中村 奨吾  0-0        2

# %%
#40824
df[40820:40826]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824]
# Out:
#        投球数      球種       球速                     結果     投手    打者  スコア  アウトカウント
# 40820    1  カットボール  139km/h                    空振り  田中 靖洋  宗 佑磨  3-2        2
# 40821    2  カットボール  140km/h          空振り  [ワンバウンド]  田中 靖洋  宗 佑磨  3-2        2
# 40822    3  カットボール  136km/h                   ファウル  田中 靖洋  宗 佑磨  3-2        2
# 40823    4  カットボール  134km/h                   ファウル  田中 靖洋  宗 佑磨  3-2        2
# 40824    5    シュート  147km/h  ボール  [ランエンドヒット、送球できず]  田中 靖洋  宗 佑磨  3-2        2
# 40825    1  カットボール  139km/h                    空振り  田中 靖洋  宗 佑磨  3-2        2

# %%
#41577
df[41570:41573]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,]
# Out:
#        投球数     球種       球速                  結果     投手     打者  スコア  アウトカウント
# 41570    1  スライダー  134km/h                 ボール  田中 将大  マーティン  1-0        1
# 41571    2  ストレート  142km/h  ボール  [リプレー検証後判定覆る]  田中 将大  マーティン  1-0        1
# 41572    1  スライダー  134km/h                 ボール  田中 将大  マーティン  1-0        1

# %%
#64563
df[64552:64557]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,]
# Out:
#        投球数     球種       球速                               結果     投手     打者  \
# 64552    1    カーブ  111km/h                              ボール  田嶋 大樹  中村 奨吾
# 64553    2   フォーク  135km/h                              ボール  田嶋 大樹  中村 奨吾
# 64554    3  ストレート  143km/h                              見逃し  田嶋 大樹  中村 奨吾
# 64555    4  ツーシーム  137km/h  見逃し  [ヘッドスライディング、リプレー検証後判定変わらず]  田嶋 大樹  中村 奨吾
# 64556    1    カーブ  111km/h                              ボール  田嶋 大樹  中村 奨吾
#
#        スコア  アウトカウント
# 64552  0-0        0
# 64553  0-0        0
# 64554  0-0        0
# 64555  0-0        0
# 64556  0-0        0

# %%
#68160
df[68145:68150]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,]
# Out:
#        投球数     球種       球速                    結果     投手    打者  スコア  アウトカウント
# 68145    1  スライダー  133km/h                   ボール  本田 圭佑  太田 光  2-1        2
# 68146    2   フォーク  131km/h                   ボール  本田 圭佑  太田 光  2-1        2
# 68147    3   フォーク  132km/h                   見逃し  本田 圭佑  太田 光  2-1        2
# 68148    4  ストレート  141km/h  ボール  [リプレー検証後判定変わらず]  本田 圭佑  太田 光  2-1        2
# 68149    1  スライダー  133km/h                   ボール  本田 圭佑  太田 光  2-1        2

# %%
#83641
df[83629:83636]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634]
# Out:
#        投球数       球種       球速                          結果     投手    打者  スコア  \
# 83629    1    ストレート  148km/h                        ファウル  上沢 直之  丸 佳浩  2-2
# 83630    2  チェンジアップ  131km/h               ボール  [ワンバウンド]  上沢 直之  丸 佳浩  2-2
# 83631    3  ナックルカーブ  120km/h                         ボール  上沢 直之  丸 佳浩  2-2
# 83632    4    ストレート  149km/h                         ボール  上沢 直之  丸 佳浩  2-2
# 83633    5    ストレート  148km/h                        ファウル  上沢 直之  丸 佳浩  2-2
# 83634    6    ストレート  147km/h  ファウル  [ライン際、リプレー検証後判定変わらず]  上沢 直之  丸 佳浩  2-2
# 83635    1    ストレート  148km/h                        ファウル  上沢 直之  丸 佳浩  2-2
#
#        アウトカウント
# 83629        2
# 83630        2
# 83631        2
# 83632        2
# 83633        2
# 83634        2
# 83635        2

# %%
#102344
df[102337:102341]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339]
# Out:
#         投球数     球種       球速                          結果     投手    打者  スコア  \
# 102337    1  スライダー  129km/h                         見逃し  濵口 遥大  松本 剛  2-2
# 102338    2  スライダー  131km/h                         ボール  濵口 遥大  松本 剛  2-2
# 102339    3  ストレート  138km/h  ボール  [送球がバウンド、リプレー検証後判定覆る]  濵口 遥大  松本 剛  2-2
# 102340    1  スライダー  129km/h                         見逃し  濵口 遥大  松本 剛  2-2
#
#         アウトカウント
# 102337        2
# 102338        2
# 102339        2
# 102340        2

# %%
#106819
df[106808:106813]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811]
# Out:
#         投球数     球種       球速                    結果     投手     打者  スコア  アウトカウント
# 106808    1  ストレート  149km/h                   空振り  伊勢 大夢  松川 虎生  1-1        2
# 106809    2  ストレート        -         ボール  [ピッチアウト]  伊勢 大夢  松川 虎生  1-1        2
# 106810    3  ストレート  149km/h                   ボール  伊勢 大夢  松川 虎生  1-1        2
# 106811    4  スライダー        -  見逃し  [リプレー検証後判定変わらず]  伊勢 大夢  松川 虎生  1-1        2
# 106812    1  ストレート  149km/h                   空振り  伊勢 大夢  松川 虎生  1-1        2

# %%
#110306
df[110297:110302]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,]
# Out:
#         投球数     球種       球速                               結果     投手     打者  \
# 110297    1   フォーク  136km/h                    ボール  [ワンバウンド]  北山 亘基  髙部 瑛斗
# 110298    2  ストレート  149km/h                     ファウル  [ライン際]  北山 亘基  髙部 瑛斗
# 110299    3  ストレート  151km/h                             ファウル  北山 亘基  髙部 瑛斗
# 110300    4  ストレート  149km/h  ボール  [リプレー検証後判定変わらず、ヘッドスライディング]  北山 亘基  髙部 瑛斗
# 110301    1   フォーク  136km/h                    ボール  [ワンバウンド]  北山 亘基  髙部 瑛斗
#
#         スコア  アウトカウント
# 110297  4-4        0
# 110298  4-4        0
# 110299  4-4        0
# 110300  4-4        0
# 110301  4-4        1

# %%
#122478
df[122472:122476]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474]
# Out:
#         投球数     球種       球速                                  結果     投手  \
# 122472    1  ストレート  152km/h                        ボール  [バント構え]  平内 龍太
# 122473    2  ストレート  151km/h                     ファウル  [バントファウル]  平内 龍太
# 122474    3  ストレート  150km/h  ファウル  [バントファウル、珍プレイ、リプレー検証後判定変わらず]  平内 龍太
# 122475    1  ストレート  152km/h                        ボール  [バント構え]  平内 龍太
#
#             打者  スコア  アウトカウント
# 122472  山崎 晃大朗  8-8        0
# 122473  山崎 晃大朗  8-8        0
# 122474  山崎 晃大朗  8-8        0
# 122475  山崎 晃大朗  8-8        0

# %%
#126436
df[126430:126434]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432]
# Out:
#         投球数      球種       球速                    結果    投手     打者  スコア  アウトカウント
# 126430    1  カットボール  131km/h      ファウル  [ヒットエンドラン]  ガンケル  桑原 将志  2-2        1
# 126431    2   ストレート  143km/h                   ボール  ガンケル  桑原 将志  2-2        1
# 126432    3   ツーシーム  140km/h  ボール  [リプレー検証後判定変わらず]  ガンケル  桑原 将志  2-2        1
# 126433    1  カットボール  131km/h      ファウル  [ヒットエンドラン]  ガンケル  桑原 将志  2-2        1

# %%
#129199
df[129186:129193]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,]
# Out:
#         投球数     球種       球速                  結果     投手     打者  スコア  アウトカウント
# 129186    1  ストレート  146km/h                 ボール  田中 将大  安田 尚憲  0-1        2
# 129187    2  スライダー  131km/h                 見逃し  田中 将大  安田 尚憲  0-1        2
# 129188    3  ストレート  148km/h                 ボール  田中 将大  安田 尚憲  0-1        2
# 129189    4  スプリット  139km/h                 空振り  田中 将大  安田 尚憲  0-1        2
# 129190    5  スプリット  141km/h    ファウル  [ランエンドヒット]  田中 将大  安田 尚憲  0-1        2
# 129191    6  ストレート  150km/h  ボール  [リプレー検証後判定覆る]  田中 将大  安田 尚憲  0-1        2
# 129192    1  ストレート  146km/h                 ボール  田中 将大  安田 尚憲  0-1        2

# %%
#143053
df[143045:143050]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048]
# Out:
#         投球数     球種       球速                            結果     投手     打者  スコア  \
# 143045    1  ストレート  149km/h                           ボール  大関 友久  中川 圭太  1-0
# 143046    2   フォーク  137km/h                           見逃し  大関 友久  中川 圭太  1-0
# 143047    3   フォーク  138km/h                           ボール  大関 友久  中川 圭太  1-0
# 143048    4  ストレート  148km/h  ボール  [送球がバウンド、リプレー検証後判定変わらず]  大関 友久  中川 圭太  1-0
# 143049    1  ストレート  149km/h                           ボール  大関 友久  中川 圭太  1-0
#
#         アウトカウント
# 143045        1
# 143046        1
# 143047        1
# 143048        1
# 143049        1

# %%
#149814
df[149808:149812]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#]
# Out:
#         投球数      球種       球速                          結果     投手     打者  スコア  \
# 149808    1  カットボール  135km/h                         ボール  田嶋 大樹  浅村 栄斗  4-1
# 149809    2   ツーシーム  141km/h                         ボール  田嶋 大樹  浅村 栄斗  4-1
# 149810    3   スライダー  126km/h  ファウル  [ポール際、リプレー検証後判定変わらず]  田嶋 大樹  浅村 栄斗  4-1
# 149811    1  カットボール  135km/h                         ボール  田嶋 大樹  浅村 栄斗  4-1
#
#         アウトカウント
# 149808        0
# 149809        0
# 149810        0
# 149811        0

# %%
#158376
df[158369:158372]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,]
# Out:
#         投球数     球種       球速                          結果     投手    打者  スコア  \
# 158369    1  ストレート  146km/h                         ボール  田中 将大  森 友哉  2-0
# 158370    2  スライダー  134km/h  ファウル  [ライン際、リプレー検証後判定変わらず]  田中 将大  森 友哉  2-0
# 158371    1  ストレート  146km/h                         ボール  田中 将大  森 友哉  2-0
#
#         アウトカウント
# 158369        0
# 158370        0
# 158371        0

# %%
#159440
df[159431:159434]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,]
# Out:
#         投球数       球種       球速                    結果   投手     打者  スコア  アウトカウント
# 159431    1    ストレート  149km/h                   ボール  ロメロ  今川 優馬  3-4        2
# 159432    2  チェンジアップ  133km/h  空振り  [リプレー検証後判定変わらず]  ロメロ  今川 優馬  3-4        2
# 159433    1    ストレート  149km/h                   ボール  ロメロ  今川 優馬  3-4        2

# %%
#188820
df[188811:188816]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#]
# Out:
#         投球数     球種       球速                             結果     投手      打者  \
# 188811    1  ストレート  153km/h          見逃し  [セーフティバント、バント構え]  ブセニッツ  アルカンタラ
# 188812    2  スプリット  149km/h                  ボール  [ワンバウンド]  ブセニッツ  アルカンタラ
# 188813    3    カーブ  135km/h  ボール  [セーフティバント、バント構え、ハーフスイング]  ブセニッツ  アルカンタラ
# 188814    4  ストレート  153km/h  空振り  [ランエンドヒット、リプレー検証後判定変わらず]  ブセニッツ  アルカンタラ
# 188815    1  ストレート  153km/h          見逃し  [セーフティバント、バント構え]  ブセニッツ  アルカンタラ
#
#         スコア  アウトカウント
# 188811  1-0        0
# 188812  1-0        0
# 188813  1-0        0
# 188814  1-0        0
# 188815  1-0        0

# %%
#192896
df[192889:192893]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891]
# Out:
#         投球数      球種       球速                    結果     投手      打者  スコア  \
# 192889    1   ストレート        -                   ボール  平内 龍太  梅野 隆太郎  4-0
# 192890    2  カットボール  135km/h                   ボール  平内 龍太  梅野 隆太郎  4-0
# 192891    3   ストレート  150km/h  見逃し  [リプレー検証後判定変わらず]  平内 龍太  梅野 隆太郎  4-0
# 192892    1   ストレート        -                   ボール  平内 龍太  梅野 隆太郎  4-0
#
#         アウトカウント
# 192889        2
# 192890        2
# 192891        2
# 192892        2

# %%
#193365
df[193357:193361]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,]
# Out:
#         投球数      球種       球速                    結果      投手    打者  スコア  アウトカウント
# 193357    1   ストレート  137km/h                   ボール  上田 洸太朗  サンタナ  0-0        1
# 193358    2  カットボール  132km/h                   ボール  上田 洸太朗  サンタナ  0-0        1
# 193359    3  カットボール        -  見逃し  [リプレー検証後判定変わらず]  上田 洸太朗  サンタナ  0-0        1
# 193360    1   ストレート  137km/h                   ボール  上田 洸太朗  サンタナ  0-0        1

# %%
#195466
df[195452:195458]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
#195456,]
# Out:
#         投球数     球種       球速                          結果     投手     打者  スコア  \
# 195452    1  ストレート  154km/h                         ボール  北山 亘基  中川 圭太  0-0
# 195453    2  ストレート  150km/h    ファウル  [セーフティバント、バントファウル]  北山 亘基  中川 圭太  0-0
# 195454    3  ストレート  154km/h                         見逃し  北山 亘基  中川 圭太  0-0
# 195455    4  ストレート  155km/h               ボール  [打者のけぞる]  北山 亘基  中川 圭太  0-0
# 195456    5  スライダー  127km/h  ファウル  [ポール際、リプレー検証後判定変わらず]  北山 亘基  中川 圭太  0-0
# 195457    1  ストレート  154km/h                         ボール  北山 亘基  中川 圭太  0-0
#
#         アウトカウント
# 195452        1
# 195453        1
# 195454        1
# 195455        1
# 195456        1
# 195457        1

# %%
#195482
df[195471:195477]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
#195456,195471,195472,195473,195474,195475,]
# Out:
#         投球数     球種       球速                                     結果     投手  \
# 195471    1  ストレート  147km/h                                    ボール  北山 亘基
# 195472    2  ストレート  151km/h                                    ボール  北山 亘基
# 195473    3  ストレート  150km/h                                   ファウル  北山 亘基
# 195474    4  ストレート  151km/h                       ファウル  [ランエンドヒット]  北山 亘基
# 195475    5  ストレート        -  ボール  [ランエンドヒット、送球がバウンド、リプレー検証後判定変わらず]  北山 亘基
# 195476    1  ストレート  147km/h                                    ボール  北山 亘基
#
#            打者  スコア  アウトカウント
# 195471  頓宮 裕真  0-0        2
# 195472  頓宮 裕真  0-0        2
# 195473  頓宮 裕真  0-0        2
# 195474  頓宮 裕真  0-0        2
# 195475  頓宮 裕真  0-0        2
# 195476  頓宮 裕真  0-0        2

# %%
#198201
df[198191:198197]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
#195456,195471,195472,195473,195474,195475,198191,198192,198193,198194,
#198195,]
# Out:
#         投球数     球種       球速                                      結果     投手  \
# 198191    1  ストレート  148km/h                                     ボール  髙橋 宏斗
# 198192    2  スプリット  138km/h                                     空振り  髙橋 宏斗
# 198193    3  ストレート  150km/h                                     ボール  髙橋 宏斗
# 198194    4  ストレート  149km/h                                     ボール  髙橋 宏斗
# 198195    5  スプリット  137km/h  空振り  [ランエンドヒット、ヘッドスライディング、リプレー検証後判定覆る]  髙橋 宏斗
# 198196    1  ストレート  148km/h                                     ボール  髙橋 宏斗
#
#            打者  スコア  アウトカウント
# 198191  松原 聖弥  1-2        2
# 198192  松原 聖弥  1-2        2
# 198193  松原 聖弥  1-2        2
# 198194  松原 聖弥  1-2        2
# 198195  松原 聖弥  1-2        2
# 198196  松原 聖弥  1-2        2

# %%
#199183
df[199177:199180]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
#195456,195471,195472,195473,195474,195475,198191,198192,198193,198194,
#198195,199177,199178,]
# Out:
#         投球数     球種       球速                             結果     投手      打者  \
# 199177    1  ストレート  143km/h                            ボール  大貫 晋一  山崎 晃大朗
# 199178    2  スプリット        -  空振り  [ランエンドヒット、リプレー検証後判定変わらず]  大貫 晋一  山崎 晃大朗
# 199179    1  ストレート  143km/h                            ボール  大貫 晋一  山崎 晃大朗
#
#         スコア  アウトカウント
# 199177  0-0        1
# 199178  0-0        1
# 199179  0-0        1

# %%
#206145
df[206135:206140]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
#195456,195471,195472,195473,195474,195475,198191,198192,198193,198194,
#198195,199177,199178,206135,206136,206137,206138,]
# Out:
#         投球数      球種       球速                                            結果  \
# 206135    1   ストレート  144km/h                                          ファウル
# 206136    2   ストレート  146km/h                                           ボール
# 206137    3  カットボール  138km/h                                          ファウル
# 206138    4    フォーク  134km/h  ボール  [ランエンドヒット、ワンバウンド、タッチをかいくぐる、リプレー検証後判定覆る]
# 206139    1   ストレート  144km/h                                          ファウル
#
#            投手     打者  スコア  アウトカウント
# 206135  髙橋 光成  近藤 健介  0-0        1
# 206136  髙橋 光成  近藤 健介  0-0        1
# 206137  髙橋 光成  近藤 健介  0-0        1
# 206138  髙橋 光成  近藤 健介  0-0        1
# 206139  髙橋 光成  近藤 健介  0-0        1

# %%
#211379
df[211373:211377]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
#195456,195471,195472,195473,195474,195475,198191,198192,198193,198194,
#198195,199177,199178,206135,206136,206137,206138,211373,211374,211375,
#]
# Out:
#         投球数       球種       球速                             結果       投手    打者  \
# 211373    1    ストレート  148km/h                            ボール  小笠原 慎之介  サンタナ
# 211374    2  ナックルカーブ  118km/h                            空振り  小笠原 慎之介  サンタナ
# 211375    3    ストレート  150km/h  空振り  [ランエンドヒット、リプレー検証後判定変わらず]  小笠原 慎之介  サンタナ
# 211376    1    ストレート  148km/h                            ボール  小笠原 慎之介  サンタナ
#
#         スコア  アウトカウント
# 211373  2-0        2
# 211374  2-0        2
# 211375  2-0        2
# 211376  2-0        2

# %%
#236842
df[236833:236837]
#array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
#36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
#40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
#68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
#106808,106809,106810,106811,110297,110298,110299,110300,122472,
#122473,122474,126430,126431,126432,129186,129187,129188,129189,
#129190,129191,143045,143046,143047,143048,149808,149809,149810,
#158369,158370,159431,159432,188811,188812,188813,188814,
#192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
#195456,195471,195472,195473,195474,195475,198191,198192,198193,198194,
#198195,199177,199178,206135,206136,206137,206138,211373,211374,211375,
#236833,236834,236835]
# Out:
#         投球数     球種       球速                             結果     投手     打者  スコア  \
# 236833    1  ストレート  151km/h                            ボール  鈴木 翔天  近藤 健介  0-3
# 236834    2  スライダー  134km/h                            ボール  鈴木 翔天  近藤 健介  0-3
# 236835    3  ストレート  151km/h  空振り  [ヒットエンドラン、リプレー検証後判定変わらず]  鈴木 翔天  近藤 健介  0-3
# 236836    1  ストレート  151km/h                            ボール  鈴木 翔天  近藤 健介  0-3
#
#         アウトカウント
# 236833        0
# 236834        0
# 236835        0
# 236836        0

# %%
array = [3061,3062,15096,15097,15098,27195,27196,27197,27198,
36863,36864,38909,38910,40569,40570,40571,40572,40820,40821,40822,
40823,40824,41570,41571,64552,64553,64554,64555,68145,68146,68147,
68148,83629,83630,83631,83632,83633,83634,102337,102338,102339,
106808,106809,106810,106811,110297,110298,110299,110300,122472,
122473,122474,126430,126431,126432,129186,129187,129188,129189,
129190,129191,143045,143046,143047,143048,149808,149809,149810,
158369,158370,159431,159432,188811,188812,188813,188814,
192889,192890,192891,193357,193358,193359,195452,195453,195454,195455,
195456,195471,195472,195473,195474,195475,198191,198192,198193,198194,
198195,199177,199178,206135,206136,206137,206138,211373,211374,211375,
236833,236834,236835]
print(array)
print(len(array))
# Out:
# [3061, 3062, 15096, 15097, 15098, 27195, 27196, 27197, 27198, 36863, 36864, 38909, 38910, 40569, 40570, 40571, 40572, 40820, 40821, 40822, 40823, 40824, 41570, 41571, 64552, 64553, 64554, 64555, 68145, 68146, 68147, 68148, 83629, 83630, 83631, 83632, 83633, 83634, 102337, 102338, 102339, 106808, 106809, 106810, 106811, 110297, 110298, 110299, 110300, 122472, 122473, 122474, 126430, 126431, 126432, 129186, 129187, 129188, 129189, 129190, 129191, 143045, 143046, 143047, 143048, 149808, 149809, 149810, 158369, 158370, 159431, 159432, 188811, 188812, 188813, 188814, 192889, 192890, 192891, 193357, 193358, 193359, 195452, 195453, 195454, 195455, 195456, 195471, 195472, 195473, 195474, 195475, 198191, 198192, 198193, 198194, 198195, 199177, 199178, 206135, 206136, 206137, 206138, 211373, 211374, 211375, 236833, 236834, 236835]
# 109

# %%
#該当箇所を削除&データフレームの該当箇所が削除されたかを確認
df = df.drop(df.index[[array]])
length = df.shape[0]
print(length)
print(238149-109)

#indexを振り直す
df = df.reset_index(drop=True)
# Out:
# 238040
# 238040
# C:\Users\yutay\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4616: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)

# %%
df.to_csv('data/allgame_result_corrected.csv',index=False)
